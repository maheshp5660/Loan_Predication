# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Pre-processing

# %%
df = pd.read_csv('loan.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe().style.background_gradient()
# Out:
# <style type="text/css">
# #T_24838_row0_col0 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_24838_row0_col1 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_24838_row0_col2 {
#   background-color: #046096;
#   color: #f1f1f1;
# }
# #T_24838_row0_col3, #T_24838_row0_col4, #T_24838_row7_col0, #T_24838_row7_col1, #T_24838_row7_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_24838_row1_col0 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_24838_row1_col1 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_24838_row1_col2 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_24838_row1_col3 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_24838_row1_col4, #T_24838_row2_col4, #T_24838_row3_col0, #T_24838_row3_col1, #T_24838_row3_col2, #T_24838_row3_col3, #T_24838_row3_col4, #T_24838_row4_col1, #T_24838_row4_col4, #T_24838_row5_col4, #T_24838_row6_col4, #T_24838_row7_col4 {
# ...

# %%
df.describe(include=["object"])
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Handling Missing value

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
plt.figure(figsize = (6,6))
sns.heatmap(df.isnull() , vmin=-1 , vmax=1)
# Out:
# <AxesSubplot:>

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
df['LoanAmount'].value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
df["Dependents"].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
df['Loan_Amount_Term'].value_counts()
# Out:
# 360.0    512
# 180.0     44
# 480.0     15
# 300.0     13
# 240.0      4
# 84.0       4
# 120.0      3
# 60.0       2
# 36.0       2
# 12.0       1
# Name: Loan_Amount_Term, dtype: int64

# %%
df['Credit_History'].value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %% [markdown]
# ## Fill Missing Value

# %%
df['Gender'].fillna('Male' , inplace=True)

# %%
df['Married'].fillna("Yes" , inplace=True)

# %%
df['Dependents'].fillna(0 , inplace=True)

# %%
df['Self_Employed'].fillna(1 ,inplace=True)

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(), inplace=True)

# %%
df['Loan_Amount_Term'].fillna(180  , inplace=True)

# %%
df['Credit_History'].fillna(1 , inplace=True)

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False       False             False
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.isnull() , cmap="viridis",vmin=-1 , vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Replace the Object  of Value

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Dependents']= df['Dependents'].replace(to_replace ='3+', value=5)

# %%
df['Dependents'].value_counts()
# Out:
# 0    345
# 1    102
# 2    101
# 5     51
# 0     15
# Name: Dependents, dtype: int64

# %%
# from sklearn.preprocessing import LabelEncoder
# # instantiate labelencoder object
# le = LabelEncoder()

# # apply le on categorical feature columns
# data[categorical_cols] = data[categorical_cols].apply(lambda col: le.fit_transform(col))    
# from sklearn.preprocessing import OneHotEncoder
# ohe = OneHotEncoder()

# #One-hot-encode the categorical columns.
# #Unfortunately outputs an array instead of dataframe.
# array_hot_encoded = ohe.fit_transform(data[categorical_cols])

# #Convert it to df
# data_hot_encoded = pd.DataFrame(array_hot_encoded, index=data.index)

# #Extract only the columns that didnt need to be encoded
# data_other_cols = data.drop(columns=categorical_cols)

# #Concatenate the two dataframes : 
# data_out = pd.concat([data_hot_encoded, data_other_cols], axis=1)

# %%
df['Gender'] = df['Gender'].replace({'Male':1 , 'Female':0})

# %%
df['Married'] = df['Married'].replace({'Yes':1 , 'No':0})

# %%
df['Education'] = df['Education'].replace({'Graduate':1,'Not Graduate':0})

# %%
df['Self_Employed'] = df['Self_Employed'].replace({'No':0,'Yes':1})

# %%
df['Property_Area'] = df['Property_Area'].replace({'Rural':0,'Semiurban':1,'Urban':2})

# %%
df['Loan_Status'] = df['Loan_Status'].replace({'N':0 , 'Y':1})

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001002       1        0          0          1              0
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 0             1.0              2            1
# 1             1.0              0            0
# ...

# %% [markdown]
# ## Exploratry Data-Analysis

# %%
plt.figure(figsize=(4,4))
sns.countplot(x = df['Gender'] , data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = df['Dependents'], data=df)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x = df['Married'] , data=df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x = df['Loan_Status'] , data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x = df['Education'] , data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
plt.figure(figsize=(4,4))
sns.countplot(x = df['Self_Employed'] , data=df)
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot(x = df['Loan_Status'] , data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x = df['Credit_History'] , data=df)
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %%
## 'Graduate':1,'Not Graduate':0

sns.countplot(x = df['Education'] , hue = 'Loan_Status' , data=df)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
##   'Yes':1 , 'No':0

plt.hist(x=df['Married'] , bins=50 , rwidth=1.2 , color='red' , label='Married')
plt.title("Loan_Status per the Married")
plt.xlabel('Married')
plt.ylabel('Loan_Status')
plt.legend()
plt.show()

# %%
## 'No':0,'Yes':1

plt.hist(x=df['Self_Employed'] , bins=50 , rwidth=0.8 , color='green' , label='Married')
plt.title("Loan_Status per the Self_Employed")
plt.xlabel('Self_Employed')
plt.ylabel('Loan_Status')
plt.legend()
plt.show()

# %%
sns.countplot(x=df["Dependents"],data=df,hue="Loan_Status")
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(x = df['Property_Area'] , data=df)
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %%
## married  = Yes':1 , 'No':0
## Dependents = 0,1,2,5,0
sns.barplot(x=df['Married'] , y=df['Dependents'] , data=df , orient = 'horizental')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='Dependents'>

# %%
sns.barplot(y="ApplicantIncome",x="Loan_Status",data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.barplot(y="ApplicantIncome",x="Gender",data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='ApplicantIncome'>

# %%
sns.countplot(x="Credit_History",hue="Loan_Status",data=df)
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %%
sns.displot(hue='Loan_Status',x='LoanAmount',data=df)

# %%
df.drop(['Loan_ID'], axis=1 , inplace=True)

# %%
df.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          1              0             5849
# 1       1        1          1          1              0             4583
# 2       1        1          0          1              1             3000
# 3       1        1          0          0              0             2583
# 4       1        0          0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              2            1
# 1              0            0
# ...

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                      Gender   Married  Education  Self_Employed  \
# Gender             1.000000  0.364569  -0.045364      -0.023918
# Married            0.364569  1.000000  -0.012304      -0.021584
# Education         -0.045364 -0.012304   1.000000       0.019059
# Self_Employed     -0.023918 -0.021584   0.019059       1.000000
# ApplicantIncome    0.058809  0.051708   0.140760       0.121356
# CoapplicantIncome  0.082912  0.075948   0.062290       0.028834
# LoanAmount         0.107930  0.147141   0.166998       0.112118
# Loan_Amount_Term  -0.064425 -0.093255   0.099673      -0.041626
# Credit_History     0.009170  0.010938   0.073658       0.041932
# Property_Area     -0.025752  0.004257   0.065243      -0.022732
# Loan_Status        0.017987  0.091478   0.085884       0.005857
#
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Gender                    0.058809           0.082912    0.107930
# ...

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr() , cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    object
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 57.7+ KB

# %%
df['Dependents'] = df['Dependents'].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int64
#  2   Dependents         614 non-null    int64
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(8)
# memory usage: 57.7 KB

# %% [markdown]
# ## Split Dataset into Train and Test

# %%
## X = df.drop(columns=['Loan_Status'],axis=1)
## Y = df['Loan_Status']

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          1              0             5849
# 1         1        1           1          1              0             4583
# 2         1        1           0          1              1             3000
# 3         1        1           0          0              0             2583
# 4         1        0           0          1              0             6000
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          1              0             2900
# 610       1        1           5          1              0             4106
# 611       1        1           1          1              0             8072
# 612       1        1           2          1              0             7583
# 613       0        0           0          1              1             4583
#
# ...

# %%
x.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
x.shape
# Out:
# (614, 11)

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
y.shape
# Out:
# (614,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test , y_train,y_test  = train_test_split(x,y , test_size = 0.30 , random_state = 42 )

# %%
x_train.shape
# Out:
# (429, 11)

# %%
y_train.shape
# Out:
# (429,)

# %%
x_test.shape
# Out:
# (185, 11)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x_train)
x_train = sc.transform(x_train)
x_test  = sc.transform(x_test)

# %% [markdown]
# ## Build Model

# %%
from sklearn.svm import SVC
classification = SVC()
classification.fit(x_train,y_train)
classification.score(x_test , y_test)
# Out:
# 0.7837837837837838

# %%
y_pred = classification.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy  on testing : ", accuracy_score(y_test, y_pred))
a = accuracy_score(y_test, y_pred)
# Out:
# Accuracy  on testing :  0.7837837837837838

# %%
x_pred = classification.predict(x_train)

# %%
print("Accuracy on training: " , accuracy_score(x_pred , y_train))
# Out:
# Accuracy on training:  0.8298368298368298

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)




cr = classification_report(y_test, y_pred)
print("Classification Report:")
print(cr)
# Out:
# Confusion Matrix:
# [[ 26  39]
#  [  1 119]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.40      0.57        65
#            1       0.75      0.99      0.86       120
#
#     accuracy                           0.78       185
#    macro avg       0.86      0.70      0.71       185
# weighted avg       0.83      0.78      0.75       185

# %%
data = [['SVM' ,a]]

df1 = pd.DataFrame(data,  columns=['Model', 'acccuracy'])

# %%
df1.head()
# Out:
#   Model  acccuracy
# 0   SVM   0.783784

# %% [markdown]
# ## Model Prediction

# %%
x_sample = np.array([[1 ,0 ,0 ,1 ,0 ,5849 ,0.0 ,146.412162 ,360.0 ,1.0 ,2 ],[1 ,1 ,0 ,0 ,0 ,2583 ,2358.0 ,120.000000 ,360.0 ,1.0 ,2 ],
                               [1 ,1 ,2 ,1 ,0 ,7583 ,0.0 ,187.0 ,360.0 ,1.0 ,2 ]])
sc.fit(x_sample)
x_sample = sc.transform(x_sample)

x_sample
# Out:
# array([[ 0.        , -1.41421356, -0.70710678,  0.70710678,  0.        ,
#          0.24634966, -0.70710678, -0.17147748,  0.        ,  0.        ,
#          0.        ],
#        [ 0.        ,  0.70710678, -0.70710678, -1.41421356,  0.        ,
#         -1.32919468,  1.41421356, -1.12996953,  0.        ,  0.        ,
#          0.        ],
#        [ 0.        ,  0.70710678,  1.41421356,  0.70710678,  0.        ,
#          1.08284503, -0.70710678,  1.30144701,  0.        ,  0.        ,
#          0.        ]])

# %%
classification.predict(x_sample)
# Out:
# array([1, 1, 1])

# %% [markdown]
# ## Save Model

# %% [markdown]
# ## Pickle

# %%
import pickle 
pickle .dump(classification , open('Model_save3' , 'wb'))
model = pickle.load(open('Model_save3' , 'rb'))
model.predict(x_sample)
# Out:
# array([1, 1, 1])
